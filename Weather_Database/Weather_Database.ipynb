# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | kepanjen
# Processing Record 5 of Set 1 | iracoubo
# Processing Record 6 of Set 1 | cam ranh
# Processing Record 7 of Set 1 | saint anthony
# Processing Record 8 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 1 | lazaro cardenas
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | tilichiki
# Processing Record 13 of Set 1 | alugan
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | carora
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | nizwa
# Processing Record 21 of Set 1 | tabas
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | gao
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | amga
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 1 | saint-pierre
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | porto belo
# Processing Record 34 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 1 | payo
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | ust-donetskiy
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | zawiercie
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | caraquet
# Processing Record 45 of Set 1 | helong
# Processing Record 46 of Set 1 | ahipara
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | pachino
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | karpogory
# Processing Record 6 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 7 of Set 2 | yulara
# Processing Record 8 of Set 2 | stoilesti
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | whitehorse
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | kamaishi
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | najran
# Processing Record 15 of Set 2 | laela
# Processing Record 16 of Set 2 | sinnamary
# Processing Record 17 of Set 2 | suhbaatar
# Processing Record 18 of Set 2 | paranaiba
# Processing Record 19 of Set 2 | reims
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | husavik
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | latung
# Processing Record 25 of Set 2 | hualmay
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | chimoio
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | marbella
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 33 of Set 2 | altay
# Processing Record 34 of Set 2 | juneau
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | taksimo
# Processing Record 37 of Set 2 | paamiut
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 42 of Set 2 | hearst
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | douglas
# Processing Record 46 of Set 2 | shakiso
# Processing Record 47 of Set 2 | vagur
# Processing Record 48 of Set 2 | kargopol
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | trussville
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | leh
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | marsa matruh
# Processing Record 7 of Set 3 | walla walla
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | tambacounda
# Processing Record 11 of Set 3 | dukat
# Processing Record 12 of Set 3 | kvarkeno
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | hervey bay
# Processing Record 15 of Set 3 | ca mau
# Processing Record 16 of Set 3 | port hardy
# Processing Record 17 of Set 3 | mandal
# Processing Record 18 of Set 3 | babushkin
# Processing Record 19 of Set 3 | gushikawa
# Processing Record 20 of Set 3 | tecoanapa
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | aklavik
# Processing Record 23 of Set 3 | emba
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | svetlogorsk
# Processing Record 26 of Set 3 | sakakah
# Processing Record 27 of Set 3 | komsomolskiy
# Processing Record 28 of Set 3 | yongan
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | coahuayana
# Processing Record 31 of Set 3 | goundam
# Processing Record 32 of Set 3 | te anau
# Processing Record 33 of Set 3 | guiratinga
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | taoudenni
# Processing Record 36 of Set 3 | sile
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | vila velha
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | broken hill
# Processing Record 41 of Set 3 | tieling
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | mabaruma
# Processing Record 46 of Set 3 | sur
# Processing Record 47 of Set 3 | mezhdurechenskiy
# Processing Record 48 of Set 3 | pitimbu
# Processing Record 49 of Set 3 | otterup
# Processing Record 50 of Set 3 | zhongshu
# Processing Record 1 of Set 4 | fuente palmera
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | nipawin
# Processing Record 5 of Set 4 | opuwo
# Processing Record 6 of Set 4 | sept-iles
# Processing Record 7 of Set 4 | farkhor
# Processing Record 8 of Set 4 | ayagoz
# Processing Record 9 of Set 4 | nishihara
# Processing Record 10 of Set 4 | yabrud
# Processing Record 11 of Set 4 | kambove
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | saryg-sep
# Processing Record 14 of Set 4 | cabo san lucas
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | yatou
# Processing Record 22 of Set 4 | kajaani
# Processing Record 23 of Set 4 | ponta do sol
# Processing Record 24 of Set 4 | puerto baquerizo moreno
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | mounana
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | levin
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | bonavista
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | rocha
# Processing Record 35 of Set 4 | contamana
# Processing Record 36 of Set 4 | riyadh
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | jumla
# Processing Record 39 of Set 4 | stykkisholmur
# Processing Record 40 of Set 4 | yantal
# Processing Record 41 of Set 4 | daru
# Processing Record 42 of Set 4 | campbell river
# Processing Record 43 of Set 4 | kieta
# Processing Record 44 of Set 4 | remontnoye
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | kiunga
# Processing Record 47 of Set 4 | ambon
# Processing Record 48 of Set 4 | harper
# Processing Record 49 of Set 4 | humaita
# Processing Record 50 of Set 4 | hun
# Processing Record 1 of Set 5 | charters towers
# Processing Record 2 of Set 5 | tateyama
# Processing Record 3 of Set 5 | denpasar
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | ahuimanu
# Processing Record 7 of Set 5 | coihaique
# Processing Record 8 of Set 5 | eskil
# Processing Record 9 of Set 5 | volksrust
# Processing Record 10 of Set 5 | pangkalanbuun
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 5 | marsh harbour
# Processing Record 14 of Set 5 | saskylakh
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | kloulklubed
# Processing Record 17 of Set 5 | mehamn
# Processing Record 18 of Set 5 | jaguaquara
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | san vicente
# Processing Record 21 of Set 5 | takoradi
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | bilma
# Processing Record 24 of Set 5 | nalut
# Processing Record 25 of Set 5 | ambilobe
# Processing Record 26 of Set 5 | esparta
# Processing Record 27 of Set 5 | prince rupert
# Processing Record 28 of Set 5 | belozerskoye
# Processing Record 29 of Set 5 | havelock
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | novyy urengoy
# Processing Record 32 of Set 5 | grand gaube
# Processing Record 33 of Set 5 | colquechaca
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | bluff
# Processing Record 36 of Set 5 | aswan
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | kungurtug
# Processing Record 39 of Set 5 | ullapool
# Processing Record 40 of Set 5 | pathri
# Processing Record 41 of Set 5 | genhe
# Processing Record 42 of Set 5 | kangaatsiaq
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | mala vyska
# Processing Record 46 of Set 5 | vriezenveen
# Processing Record 47 of Set 5 | xique-xique
# Processing Record 48 of Set 5 | honiara
# Processing Record 49 of Set 5 | makakilo city
# Processing Record 50 of Set 5 | tucurui
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | rosetta
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 6 | changji
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | inverness
# Processing Record 8 of Set 6 | pathein
# Processing Record 9 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 10 of Set 6 | itarema
# Processing Record 11 of Set 6 | taltal
# Processing Record 12 of Set 6 | mount isa
# Processing Record 13 of Set 6 | boynton beach
# Processing Record 14 of Set 6 | bubaque
# Processing Record 15 of Set 6 | svogerslev
# Processing Record 16 of Set 6 | lianzhou
# Processing Record 17 of Set 6 | byron bay
# Processing Record 18 of Set 6 | ishigaki
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | saint-georges
# Processing Record 21 of Set 6 | mega
# Processing Record 22 of Set 6 | yining
# Processing Record 23 of Set 6 | kerrville
# Processing Record 24 of Set 6 | haines junction
# Processing Record 25 of Set 6 | kalmunai
# Processing Record 26 of Set 6 | alta floresta
# Processing Record 27 of Set 6 | roebourne
# Processing Record 28 of Set 6 | ngama
# Processing Record 29 of Set 6 | yerbogachen
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | doctor arroyo
# Processing Record 32 of Set 6 | bengkulu
# Processing Record 33 of Set 6 | bontang
# Processing Record 34 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | cherskiy
# Processing Record 36 of Set 6 | uyutne
# Processing Record 37 of Set 6 | alburikent
# Processing Record 38 of Set 6 | meulaboh
# Processing Record 39 of Set 6 | rabo de peixe
# Processing Record 40 of Set 6 | virden
# Processing Record 41 of Set 6 | yaring
# Processing Record 42 of Set 6 | helena
# Processing Record 43 of Set 6 | karanganyar
# Processing Record 44 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 45 of Set 6 | majenang
# Processing Record 46 of Set 6 | suntar
# Processing Record 47 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 6 | vardo
# Processing Record 49 of Set 6 | kathu
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | bariadi
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | nueve de julio
# Processing Record 4 of Set 7 | yarmouth
# Processing Record 5 of Set 7 | monrovia
# Processing Record 6 of Set 7 | killybegs
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | dawei
# Processing Record 9 of Set 7 | hammerfest
# Processing Record 10 of Set 7 | basco
# Processing Record 11 of Set 7 | nelson bay
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | tokur
# Processing Record 14 of Set 7 | comodoro rivadavia
# Processing Record 15 of Set 7 | valleyview
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | geraldton
# Processing Record 18 of Set 7 | port blair
# Processing Record 19 of Set 7 | rouvroy
# Processing Record 20 of Set 7 | new norfolk
# Processing Record 21 of Set 7 | nichinan
# Processing Record 22 of Set 7 | fuerte olimpo
# Processing Record 23 of Set 7 | santa marinella
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 26 of Set 7 | uruzgan
# Processing Record 27 of Set 7 | kaitangata
# Processing Record 28 of Set 7 | barrow
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | vostok
# Processing Record 31 of Set 7 | lavrentiya
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | urumqi
# Processing Record 34 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 7 | half moon bay
# Processing Record 38 of Set 7 | khatanga
# Processing Record 39 of Set 7 | baykit
# Processing Record 40 of Set 7 | serafimovich
# Processing Record 41 of Set 7 | eatonton
# Processing Record 42 of Set 7 | porto velho
# Processing Record 43 of Set 7 | eruwa
# Processing Record 44 of Set 7 | mahebourg
# Processing Record 45 of Set 7 | rockport
# Processing Record 46 of Set 7 | fairmount
# Processing Record 47 of Set 7 | kyabe
# Processing Record 48 of Set 7 | vaitape
# Processing Record 49 of Set 7 | bahia blanca
# Processing Record 50 of Set 7 | nemuro
# Processing Record 1 of Set 8 | hayden
# Processing Record 2 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 8 | alice springs
# Processing Record 4 of Set 8 | chaumont
# Processing Record 5 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 8 | lahat
# Processing Record 7 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 8 | manoel urbano
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | dmitriyevka
# Processing Record 11 of Set 8 | kimparana
# Processing Record 12 of Set 8 | doha
# Processing Record 13 of Set 8 | tiznit
# Processing Record 14 of Set 8 | lumphat
# Processing Record 15 of Set 8 | olga
# Processing Record 16 of Set 8 | riachao das neves
# Processing Record 17 of Set 8 | lompoc
# Processing Record 18 of Set 8 | codrington
# Processing Record 19 of Set 8 | sonoita
# Processing Record 20 of Set 8 | portland
# Processing Record 21 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 22 of Set 8 | imbituba
# Processing Record 23 of Set 8 | aksarka
# Processing Record 24 of Set 8 | bakchar
# Processing Record 25 of Set 8 | merauke
# Processing Record 26 of Set 8 | ampanihy
# Processing Record 27 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 8 | port keats
# Processing Record 29 of Set 8 | avila
# Processing Record 30 of Set 8 | fort nelson
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | lososina
# Processing Record 33 of Set 8 | oktyabrskiy
# Processing Record 34 of Set 8 | imeni poliny osipenko
# Processing Record 35 of Set 8 | sena madureira
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | ixtapa
# Processing Record 38 of Set 8 | westport
# Processing Record 39 of Set 8 | mouila
# Processing Record 40 of Set 8 | otradnoye
# Processing Record 41 of Set 8 | damavand
# Processing Record 42 of Set 8 | honningsvag
# Processing Record 43 of Set 8 | nadlac
# Processing Record 44 of Set 8 | saint-augustin
# Processing Record 45 of Set 8 | abu samrah
# Processing Record 46 of Set 8 | xinzhi
# Processing Record 47 of Set 8 | lamu
# Processing Record 48 of Set 8 | tchibanga
# Processing Record 49 of Set 8 | pisco
# Processing Record 50 of Set 8 | shingu
# Processing Record 1 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 9 | sao luiz gonzaga
# Processing Record 3 of Set 9 | luang prabang
# Processing Record 4 of Set 9 | san juan de arama
# Processing Record 5 of Set 9 | veraval
# Processing Record 6 of Set 9 | kestel
# Processing Record 7 of Set 9 | kawambwa
# Processing Record 8 of Set 9 | abeche
# Processing Record 9 of Set 9 | awjilah
# Processing Record 10 of Set 9 | kruisfontein
# Processing Record 11 of Set 9 | oistins
# Processing Record 12 of Set 9 | shubarkuduk
# Processing Record 13 of Set 9 | thunder bay
# Processing Record 14 of Set 9 | antioch
# Processing Record 15 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 16 of Set 9 | almaznyy
# Processing Record 17 of Set 9 | nome
# Processing Record 18 of Set 9 | tura
# Processing Record 19 of Set 9 | myrtle beach
# Processing Record 20 of Set 9 | balkanabat
# Processing Record 21 of Set 9 | kaeo
# Processing Record 22 of Set 9 | karatsu
# Processing Record 23 of Set 9 | kabwe
# Processing Record 24 of Set 9 | yakeshi
# Processing Record 25 of Set 9 | nsanje
# Processing Record 26 of Set 9 | marzuq
# Processing Record 27 of Set 9 | ostrovnoy
# Processing Record 28 of Set 9 | tarhunah
# City not found. Skipping...
# Processing Record 29 of Set 9 | ulaangom
# Processing Record 30 of Set 9 | grindavik
# Processing Record 31 of Set 9 | la rioja
# Processing Record 32 of Set 9 | jalingo
# Processing Record 33 of Set 9 | hare bay
# Processing Record 34 of Set 9 | bandarbeyla
# Processing Record 35 of Set 9 | tabuk
# Processing Record 36 of Set 9 | eyl
# Processing Record 37 of Set 9 | los llanos de aridane
# Processing Record 38 of Set 9 | sibolga
# Processing Record 39 of Set 9 | minab
# Processing Record 40 of Set 9 | richards bay
# Processing Record 41 of Set 9 | novopavlovka
# Processing Record 42 of Set 9 | khanpur
# Processing Record 43 of Set 9 | progreso
# Processing Record 44 of Set 9 | azoyu
# Processing Record 45 of Set 9 | banjar
# Processing Record 46 of Set 9 | lagoa
# Processing Record 47 of Set 9 | kinablangan
# Processing Record 48 of Set 9 | port hedland
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 10 | mullovka
# Processing Record 2 of Set 10 | kipini
# Processing Record 3 of Set 10 | college
# Processing Record 4 of Set 10 | camacha
# Processing Record 5 of Set 10 | newport
# Processing Record 6 of Set 10 | ajijic
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | melfi
# Processing Record 9 of Set 10 | spas-klepiki
# Processing Record 10 of Set 10 | izhmorskiy
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | turukhansk
# Processing Record 13 of Set 10 | olinda
# Processing Record 14 of Set 10 | ingleside
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | sarakhs
# Processing Record 17 of Set 10 | asau
# Processing Record 18 of Set 10 | kuusamo
# Processing Record 19 of Set 10 | kindersley
# Processing Record 20 of Set 10 | bosobolo
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | vestmannaeyjar
# Processing Record 24 of Set 10 | zhangjiakou
# Processing Record 25 of Set 10 | oussouye
# Processing Record 26 of Set 10 | bend
# Processing Record 27 of Set 10 | talnakh
# Processing Record 28 of Set 10 | gewane
# Processing Record 29 of Set 10 | maua
# Processing Record 30 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 10 | nanakuli
# Processing Record 32 of Set 10 | zelenoborskiy
# Processing Record 33 of Set 10 | tanout
# Processing Record 34 of Set 10 | ray
# Processing Record 35 of Set 10 | maxixe
# Processing Record 36 of Set 10 | nantucket
# Processing Record 37 of Set 10 | lindi
# Processing Record 38 of Set 10 | caravelas
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | wichian buri
# Processing Record 41 of Set 10 | xochistlahuaca
# Processing Record 42 of Set 10 | nova londrina
# Processing Record 43 of Set 10 | sobolevo
# Processing Record 44 of Set 10 | fairbanks
# Processing Record 45 of Set 10 | walvis bay
# Processing Record 46 of Set 10 | margate
# Processing Record 47 of Set 10 | mogadishu
# Processing Record 48 of Set 10 | solnechnyy
# Processing Record 49 of Set 10 | ust-nera
# Processing Record 50 of Set 10 | kamphaeng phet
# Processing Record 1 of Set 11 | thap than
# Processing Record 2 of Set 11 | raudeberg
# Processing Record 3 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 4 of Set 11 | dromolaxia
# Processing Record 5 of Set 11 | rognedino
# Processing Record 6 of Set 11 | sorong
# Processing Record 7 of Set 11 | xudat
# Processing Record 8 of Set 11 | chernyshevskiy
# Processing Record 9 of Set 11 | calama
# Processing Record 10 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 11 | pontianak
# Processing Record 12 of Set 11 | muisne
# Processing Record 13 of Set 11 | farafangana
# Processing Record 14 of Set 11 | ilo
# Processing Record 15 of Set 11 | muhlhausen
# Processing Record 16 of Set 11 | zhiryatino
# Processing Record 17 of Set 11 | waddan
# Processing Record 18 of Set 11 | fukue
# Processing Record 19 of Set 11 | bardiyah
# Processing Record 20 of Set 11 | hami
# Processing Record 21 of Set 11 | pavlovo
# Processing Record 22 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | hispania
# Processing Record 25 of Set 11 | kalangala
# Processing Record 26 of Set 11 | general pico
# Processing Record 27 of Set 11 | pagudpud
# Processing Record 28 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 11 | almeirim
# Processing Record 30 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 11 | batsfjord
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | inhambane
# Processing Record 35 of Set 11 | kathmandu
# Processing Record 36 of Set 11 | chara
# Processing Record 37 of Set 11 | rusape
# Processing Record 38 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | tuatapere
# Processing Record 40 of Set 11 | dhidhdhoo
# Processing Record 41 of Set 11 | aktau
# Processing Record 42 of Set 11 | karratha
# Processing Record 43 of Set 11 | conde
# Processing Record 44 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 11 | gander
# Processing Record 46 of Set 11 | zaysan
# Processing Record 47 of Set 11 | arrecife
# Processing Record 48 of Set 11 | sao joao da barra
# Processing Record 49 of Set 11 | botwood
# Processing Record 50 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 12 | bajil
# Processing Record 2 of Set 12 | do rud
# City not found. Skipping...
# Processing Record 3 of Set 12 | burnie
# Processing Record 4 of Set 12 | hibbing
# Processing Record 5 of Set 12 | preobrazheniye
# Processing Record 6 of Set 12 | necochea
# Processing Record 7 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 12 | oktyabrskoye
# Processing Record 9 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 12 | bougouni
# Processing Record 11 of Set 12 | potiskum
# Processing Record 12 of Set 12 | san jeronimo
# Processing Record 13 of Set 12 | torit
# Processing Record 14 of Set 12 | boyolangu
# Processing Record 15 of Set 12 | nakusp
# Processing Record 16 of Set 12 | traverse city
# Processing Record 17 of Set 12 | sucua
# Processing Record 18 of Set 12 | gornopravdinsk
# Processing Record 19 of Set 12 | usogorsk
# Processing Record 20 of Set 12 | houma
# Processing Record 21 of Set 12 | salalah
# Processing Record 22 of Set 12 | shanghai
# Processing Record 23 of Set 12 | bullhead city
# Processing Record 24 of Set 12 | sungaipenuh
# Processing Record 25 of Set 12 | warwick
# Processing Record 26 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 12 | eregli
# Processing Record 28 of Set 12 | bocana de paiwas
# Processing Record 29 of Set 12 | vinh
# Processing Record 30 of Set 12 | avera
# Processing Record 31 of Set 12 | praia da vitoria
# Processing Record 32 of Set 12 | sokolo
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | alvorada
# Processing Record 35 of Set 12 | san carlos
# Processing Record 36 of Set 12 | norilsk
# Processing Record 37 of Set 12 | praya
# Processing Record 38 of Set 12 | angoche
# Processing Record 39 of Set 12 | synya
# Processing Record 40 of Set 12 | beyneu
# Processing Record 41 of Set 12 | zafarwal
# Processing Record 42 of Set 12 | launceston
# Processing Record 43 of Set 12 | terra santa
# Processing Record 44 of Set 12 | leeston
# Processing Record 45 of Set 12 | kapoeta
# Processing Record 46 of Set 12 | akyab
# Processing Record 47 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 12 | mallapuram
# Processing Record 49 of Set 12 | rawson
# Processing Record 50 of Set 12 | palmer
# Processing Record 1 of Set 13 | sassandra
# Processing Record 2 of Set 13 | aleksandrov gay
# Processing Record 3 of Set 13 | conceicao do araguaia
# Processing Record 4 of Set 13 | linxia
# Processing Record 5 of Set 13 | miri
# Processing Record 6 of Set 13 | constantine
# Processing Record 7 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 8 of Set 13 | mezen
# Processing Record 9 of Set 13 | bismil
# Processing Record 10 of Set 13 | nabire
# Processing Record 11 of Set 13 | porbandar
# Processing Record 12 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 13 | bonfim
# Processing Record 14 of Set 13 | san jose
# Processing Record 15 of Set 13 | key west
# Processing Record 16 of Set 13 | poshekhonye
# Processing Record 17 of Set 13 | sorland
# Processing Record 18 of Set 13 | boulder
# Processing Record 19 of Set 13 | camocim
# Processing Record 20 of Set 13 | tondon
# Processing Record 21 of Set 13 | nyaunglebin
# Processing Record 22 of Set 13 | airai
# Processing Record 23 of Set 13 | faya
# Processing Record 24 of Set 13 | wadi maliz
# Processing Record 25 of Set 13 | roald
# Processing Record 26 of Set 13 | tongliao
# Processing Record 27 of Set 13 | turbat
# Processing Record 28 of Set 13 | bintulu
# Processing Record 29 of Set 13 | elko
# Processing Record 30 of Set 13 | oranjestad
# Processing Record 31 of Set 13 | resistencia
# Processing Record 32 of Set 13 | atambua
# Processing Record 33 of Set 13 | nang rong
# Processing Record 34 of Set 13 | beaverlodge
# Processing Record 35 of Set 13 | maragogi
# Processing Record 36 of Set 13 | chapais
# Processing Record 37 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 13 | waverley
# Processing Record 39 of Set 13 | yaan
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | wakkanai
# Processing Record 42 of Set 13 | hutchinson
# Processing Record 43 of Set 13 | laguna
# Processing Record 44 of Set 13 | jiuquan
# Processing Record 45 of Set 13 | ambikapur
# Processing Record 46 of Set 13 | ginda
# Processing Record 47 of Set 13 | diffa
# Processing Record 48 of Set 13 | rovaniemi
# Processing Record 49 of Set 13 | aksu
# Processing Record 50 of Set 13 | severo-yeniseyskiy
# Processing Record 1 of Set 14 | tambura
# Processing Record 2 of Set 14 | chato
# Processing Record 3 of Set 14 | queenstown
# Processing Record 4 of Set 14 | cururupu
# Processing Record 5 of Set 14 | codajas
# Processing Record 6 of Set 14 | mount darwin
# Processing Record 7 of Set 14 | benguela
# Processing Record 8 of Set 14 | ler
# Processing Record 9 of Set 14 | bathsheba
# Processing Record 10 of Set 14 | floro
# Processing Record 11 of Set 14 | deputatskiy
# Processing Record 12 of Set 14 | lukovetskiy
# Processing Record 13 of Set 14 | poum
# Processing Record 14 of Set 14 | shieli
# Processing Record 15 of Set 14 | aquiraz
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | patacamaya
# Processing Record 18 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 14 | gorom-gorom
# Processing Record 20 of Set 14 | varanasi
# Processing Record 21 of Set 14 | belen
# Processing Record 22 of Set 14 | vrangel
# Processing Record 23 of Set 14 | woodstock
# Processing Record 24 of Set 14 | redmond
# Processing Record 25 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 14 | manzil kamil
# Processing Record 27 of Set 14 | punta de bombon
# Processing Record 28 of Set 14 | raga
# Processing Record 29 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 30 of Set 14 | tautira
# Processing Record 31 of Set 14 | maliig
# Processing Record 32 of Set 14 | amapa
# Processing Record 33 of Set 14 | woodward
# Processing Record 34 of Set 14 | velsk
# Processing Record 35 of Set 14 | kholmogory
# Processing Record 36 of Set 14 | camara de lobos
# Processing Record 37 of Set 14 | lovozero
# Processing Record 38 of Set 14 | pili
# Processing Record 39 of Set 14 | guilin
# Processing Record 40 of Set 14 | teonthar
# Processing Record 41 of Set 14 | ola
# Processing Record 42 of Set 14 | borujerd
# Processing Record 43 of Set 14 | franca
# Processing Record 44 of Set 14 | matara
# Processing Record 45 of Set 14 | kalakamati
# Processing Record 46 of Set 14 | sesheke
# Processing Record 47 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 48 of Set 14 | batticaloa
# Processing Record 49 of Set 14 | dera din panah
# City not found. Skipping...
# Processing Record 50 of Set 14 | chimbote
# Processing Record 1 of Set 15 | knysna
# Processing Record 2 of Set 15 | kusk
# City not found. Skipping...
# Processing Record 3 of Set 15 | brooks
# Processing Record 4 of Set 15 | praia
# Processing Record 5 of Set 15 | koungou
# Processing Record 6 of Set 15 | mamallapuram
# Processing Record 7 of Set 15 | yenagoa
# Processing Record 8 of Set 15 | swan river
# Processing Record 9 of Set 15 | providencia
# Processing Record 10 of Set 15 | santa rosa
# Processing Record 11 of Set 15 | orbetello
# Processing Record 12 of Set 15 | wanning
# Processing Record 13 of Set 15 | ukiah
# Processing Record 14 of Set 15 | beringovskiy
# Processing Record 15 of Set 15 | soavinandriana
# Processing Record 16 of Set 15 | prieska
# Processing Record 17 of Set 15 | novopokrovka
# Processing Record 18 of Set 15 | itinga
# Processing Record 19 of Set 15 | vila franca do campo
# Processing Record 20 of Set 15 | bairiki
# Processing Record 21 of Set 15 | bafq
# Processing Record 22 of Set 15 | kushmurun
# Processing Record 23 of Set 15 | kuryk
# Processing Record 24 of Set 15 | jacareacanga
# Processing Record 25 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 15 | baruun-urt
# Processing Record 27 of Set 15 | trairi
# Processing Record 28 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 15 | jalu
# Processing Record 30 of Set 15 | halifax
# Processing Record 31 of Set 15 | fairview
# Processing Record 32 of Set 15 | muros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Vaini -21.20 -175.20     73.40        88          75       10.29
# 1         Hermanus -34.42   19.23     55.99        89         100        7.00
# 2         Tasiilaq  65.61  -37.64     39.20        60          75       21.92
# 3         Kepanjen  -8.13  112.57     72.90        90          92        2.08
# 4         Iracoubo   5.48  -53.20     86.04        63          16        8.63
# 5         Cam Ranh  11.92  109.16     84.20        79          20        4.70
# 6    Saint Anthony  45.02  -93.22     46.40        45          90        3.74
# 7  Lazaro Cardenas  17.96 -102.20     83.52        71           0        3.60
# 8    Mar Del Plata -38.00  -57.56     53.01        53          40       16.11
# 9          Ushuaia -54.80  -68.30     33.80        80          75       29.97
#
#   Country          Weather Description
# 0      TO                broken clouds
# 1      ZA                   light rain
# 2      GL  light intensity shower rain
# 3      ID                moderate rain
# 4      GF                   light rain
# 5      VN                   few clouds
# 6      US              overcast clouds
# 7      MX                    clear sky
# 8      AR             scattered clouds
# 9      AR                broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
